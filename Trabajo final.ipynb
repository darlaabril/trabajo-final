# %% [markdown]
# # Trabajo Final

# %% [markdown]
# - Base de datos
# 1. Microdatos del [INEI](http://iinei.inei.gob.pe/microdatos/).
# módulo 4 (Salud) y módulo 34 (Sumarias) del año 2020.

# %% [markdown]
# ## Importar las bases de datos

# %%
import pandas as pd
enaho04 = pd.read_csv("Enaho01a-2020-400.csv",encoding = "latin-1")
enaho04.columns= enaho04.columns.str.lower()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import pandas as pd
#       2 enaho04 = pd.read_csv("Enaho01a-2020-400.csv",encoding = "latin-1")
#       3 enaho04.columns= enaho04.columns.str.lower()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
sumaria = pd.read_csv("Sumaria-2020.csv",encoding = "latin-1")
sumaria.columns = sumaria.columns.str.lower()
sumaria
# Out:
#         año  mes  conglome  vivienda  hogar  ubigeo  dominio  estrato  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        mieperho  totmieho  ...       linea  pobreza  tipocuestionario  \
# 0             2         2  ...  303.520996        3                 0
# 1             2         2  ...  303.520996        3                 0
# 2             6         6  ...  303.520996        3                 0
# 3             4         4  ...  303.520996        3                 0
# 4             4         4  ...  303.520996        3                 0
# ...         ...       ...  ...         ...      ...               ...
# 34485         1         1  ...  335.352234        3                 2
# 34486         1         1  ...  335.352234        3                 2
# 34487         1         1  ...  335.352234        3                 2
# 34488         4         4  ...  335.352234        3                 2
# 34489         4         4  ...  335.352234        3                 2
#
#        tipoentrevista    factor07  nconglome  sub_conglome  lineav_rpl  \
# 0                   1  149.202744       7076             0         657
# 1                   1  149.202744       7076             0         657
# 2                   1  149.202744       7076             0         657
# 3                   1   70.492592       7089             0         657
# 4                   1   70.492592       7089             0         657
# ...               ...         ...        ...           ...         ...
# 34485               1  275.828552      15122             0         657
# 34486               1  275.828552      15122             0         657
# 34487               1  275.828552      15122             0         657
# 34488               1  275.828552      15122             0         657
# 34489               1  275.828552      15122             0         657
#
#            lineav  pobrezav
# 0      560.468506         4
# 1      553.731506         4
# 2      547.194031         3
# 3      556.025330         4
# 4      548.526917         4
# ...           ...       ...
# 34485  641.312134         4
# 34486  642.814026         4
# 34487  641.782898         4
# 34488  643.160034         3
# 34489  639.233521         3
#
# [34490 rows x 179 columns]

# %% [markdown]
# ## Dimensiones

# %%
enaho04.shape      # (120346, 1052)
sumaria.shape      # (34490, 179)
# Out:
# (34490, 179)

# %%
##

# %% [markdown]
# Las variables de la ENAHO que necesitamos
# - Quedémonos con las variables ``` CONGLOME VIVIENDA HOGAR POBREZA UBIGEO``` de la sumaria.
# - Quedémonos con las variables ``` CONGLOME VIVIENDA P4026 UBIGEO ``` del módulo de salud.
#
#
# Cada una de las variables son:
#
# - POBREZA: Pobreza monetaria según la línea de pobreza.
# - P4026: Si se presenta un síntoma de covid
# - UBIGEO: Código de 6 dígitos que indica el distrito de pertenencia de la persona.
#
# CONGLOME, VIVIENDA y HOGAR son los identificadores únicos a nivel de hogar (como un key id).

# %%
sumaria = sumaria[['conglome','vivienda','hogar','pobreza','ubigeo']]
enaho04 = enaho04[['conglome','vivienda','hogar','p4026']]

# %% [markdown]
# ## Modificar la variable pobreza

# %% [markdown]
# La variable de `pobreza`, en la sumaria, está codificada como integers 1, 2 y 3. Esto corresponde a:
# `1`: hogar pobre extremo
# `2`: hogar pobre no extremo
# `3`: hogar no  pobre

# %%
sumaria["pobreza3"] = sumaria.pobreza.replace({1:"pobre extremo",2:"pobre no extremo",3:'no pobre'})
sumaria
# Out:
# <ipython-input-9-f84975c17c76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sumaria["pobreza3"] = sumaria.pobreza.replace({1:"pobre extremo",2:"pobre no extremo",3:'no pobre'})
#        conglome  vivienda  hogar  pobreza  ubigeo  pobreza3          pobreza2
# 0          5009        12     11        3   10101  no pobre  pobre no extremo
# 1          5009        41     11        3   10101  no pobre  pobre no extremo
# 2          5009        98     11        3   10101  no pobre  pobre no extremo
# 3          5015         7     11        3   10101  no pobre  pobre no extremo
# 4          5015        19     11        3   10101  no pobre  pobre no extremo
# ...         ...       ...    ...      ...     ...       ...               ...
# 34485     20305        31     11        3  250301  no pobre  pobre no extremo
# 34486     20305        52     11        3  250301  no pobre  pobre no extremo
# 34487     20305        73     11        3  250301  no pobre  pobre no extremo
# 34488     20305       116     11        3  250301  no pobre  pobre no extremo
# 34489     20305       137     11        3  250301  no pobre  pobre no extremo
#
# [34490 rows x 7 columns]

# %% [markdown]
# ## EXPLORACIÓM DE LA VARIABLE P4026, QUE MUESTRA SI UNA persona tuvo sintomas de covid

# %%
# 1 : sintomas de covid
# 0: no tiene sintomas

# %%
enaho04.p4026.value_counts()
# Out:
# 0    61970
# 0    28708
#      27424
# 1     1544
# 1      700
# Name: p4026, dtype: int64

# %%
enaho04["p4026"] = enaho04.p4026.replace({1:"posible contagiado",0:"no contagiado"})
enaho04
# Out:
#         conglome  vivienda  hogar          p4026
# 0           5009        12     11
# 1           5009        12     11
# 2           5009        41     11
# 3           5009        41     11
# 4           5009        98     11
# ...          ...       ...    ...            ...
# 120341     20305       116     11  no contagiado
# 120342     20305       137     11  no contagiado
# 120343     20305       137     11  no contagiado
# 120344     20305       137     11  no contagiado
# 120345     20305       137     11  no contagiado
#
# [120346 rows x 4 columns]

# %% [markdown]
# # MERGE DE LAS 2 BASES

# %%
merge = pd.merge(sumaria, enaho04, on=['conglome','vivienda','hogar'], how='inner')
merge
# Out:
#         conglome  vivienda  hogar  pobreza  ubigeo  pobreza3  \
# 0           5009        12     11        3   10101  no pobre
# 1           5009        12     11        3   10101  no pobre
# 2           5009        41     11        3   10101  no pobre
# 3           5009        41     11        3   10101  no pobre
# 4           5009        98     11        3   10101  no pobre
# ...          ...       ...    ...      ...     ...       ...
# 120341     20305       116     11        3  250301  no pobre
# 120342     20305       137     11        3  250301  no pobre
# 120343     20305       137     11        3  250301  no pobre
# 120344     20305       137     11        3  250301  no pobre
# 120345     20305       137     11        3  250301  no pobre
#
#                 pobreza2          p4026
# 0       pobre no extremo
# 1       pobre no extremo
# 2       pobre no extremo
# 3       pobre no extremo
# 4       pobre no extremo
# ...                  ...            ...
# 120341  pobre no extremo  no contagiado
# 120342  pobre no extremo  no contagiado
# 120343  pobre no extremo  no contagiado
# 120344  pobre no extremo  no contagiado
# 120345  pobre no extremo  no contagiado
#
# [120346 rows x 8 columns]

# %%
a2 = sumaria.groupby(["pobreza3"]).agg({'inghog2d':'mean'})
a2
# Out:
#                       inghog2d
# pobreza3
# no pobre          32014.094308
# pobre extremo      9980.110857
# pobre no extremo  15565.160905

# %% [markdown]
# 8. ¡Ahora uniremos los datos!
# Pero antes un check de sanidad: Verifica que el número  de filas de ambas bases de datos son las mismas (acuérdate que filtramos las observaciones por `result`).  La ENAHO recolecta información de estos 34,490 hogares a través de todos sus módulos. Para utilizar estos módulos a la vez, realizaremos una "unión" (merge).
#
# Une ambas bases con un _inner merge_. Recuerda que el id que identifica a cada hogar se compone de ` conglome vivienda hogar`.

# %%
merge = pd.merge(sumaria, vivienda, on=['conglome','vivienda','hogar'], how='inner')
merge
# Out:
#        conglome  vivienda  hogar  mieperho  percepho  pobreza      gashog2d  \
# 0          5009        12     11         2         2        3  25065.796875
# 1          5009        41     11         2         2        3  28650.019531
# 2          5009        98     11         6         4        3  38136.218750
# 3          5015         7     11         4         3        3  26812.154297
# 4          5015        19     11         4         3        3  63311.539062
# ...         ...       ...    ...       ...       ...      ...           ...
# 34485     20305        31     11         1         1        3  12997.472656
# 34486     20305        52     11         1         1        3  10690.595703
# 34487     20305        73     11         1         1        3  11576.803711
# 34488     20305       116     11         4         1        3  23779.029297
# 34489     20305       137     11         4         2        3  16872.869141
#
#            inghog2d  ubigeo  dependientes    diferencia  pobreza3  \
# 0      37274.425781   10101             0  12208.628906  no pobre
# 1      41967.570312   10101             0  13317.550781  no pobre
# 2      42292.535156   10101             2   4156.316406  no pobre
# 3      37866.210938   10101             1  11054.056641  no pobre
# 4      91681.960938   10101             1  28370.421875  no pobre
# ...             ...     ...           ...           ...       ...
# 34485  14227.951172  250301             0   1230.478516  no pobre
# 34486  11442.000000  250301             0    751.404297  no pobre
# 34487  12847.000000  250301             0   1270.196289  no pobre
# 34488  21009.353516  250301             3  -2769.675781  no pobre
# 34489  19822.650391  250301             2   2949.781250  no pobre
#
#                pobreza2  result nbi1 nbi2 nbi3 nbi4 nbi5
# 0      pobre no extremo       1    0    0    0    0    0
# 1      pobre no extremo       1    0    0    0    0    0
# 2      pobre no extremo       1    0    0    0    0    0
# 3      pobre no extremo       1    0    0    0    0    0
# 4      pobre no extremo       1    0    0    0    0    0
# ...                 ...     ...  ...  ...  ...  ...  ...
# 34485  pobre no extremo       1    0    0    0    0    0
# 34486  pobre no extremo       1    0    0    0    0    0
# 34487  pobre no extremo       1    1    0    0    0    0
# 34488  pobre no extremo       1    0    0    0    0    0
# 34489  pobre no extremo       1    0    0    0    0    0
#
# [34490 rows x 19 columns]

# %% [markdown]
# ## CREACIÓN DE LA VARAIBLE DEPARTAMENTO

# %%
merge["ubigeo_2"] = merge["ubigeo"].astype(str)
merge["departamento"] =  merge["ubigeo_2"].apply(lambda x: x[0:2] if len(x)>5 else x[0:1])
merge["departamento"] = merge.departamento.replace({"1":"Amazonas","2": "Ancash","3": "Apurimac","4": "Arequipa", "5":"Ayacucho", 
                                                    "6":"Cajamarca", "7":"Callao","8": "Cusco","9":"Huancavelica","10":"Huanuco",
                                                    "11":"Ica","12":"Junín", "13":"La Libertad", "14":"Lambayeque","15":"Lima", 
                                                    "16":"Loreto", "17": "Madre de Dios", "18": "Moquegua", "19":"Pasco","20": "Piura", 
                                                    "21": "Puno", "22": "San Martín", "23": "Tacna", "24": "Tumbes", "25":"Ucayali"})
merge
# Out:
#         conglome  vivienda  hogar  pobreza  ubigeo  pobreza3  \
# 0           5009        12     11        3   10101  no pobre
# 1           5009        12     11        3   10101  no pobre
# 2           5009        41     11        3   10101  no pobre
# 3           5009        41     11        3   10101  no pobre
# 4           5009        98     11        3   10101  no pobre
# ...          ...       ...    ...      ...     ...       ...
# 120341     20305       116     11        3  250301  no pobre
# 120342     20305       137     11        3  250301  no pobre
# 120343     20305       137     11        3  250301  no pobre
# 120344     20305       137     11        3  250301  no pobre
# 120345     20305       137     11        3  250301  no pobre
#
#                 pobreza2          p4026 ubigeo_2 departamento
# 0       pobre no extremo                   10101     Amazonas
# 1       pobre no extremo                   10101     Amazonas
# 2       pobre no extremo                   10101     Amazonas
# 3       pobre no extremo                   10101     Amazonas
# 4       pobre no extremo                   10101     Amazonas
# ...                  ...            ...      ...          ...
# 120341  pobre no extremo  no contagiado   250301      Ucayali
# 120342  pobre no extremo  no contagiado   250301      Ucayali
# 120343  pobre no extremo  no contagiado   250301      Ucayali
# 120344  pobre no extremo  no contagiado   250301      Ucayali
# 120345  pobre no extremo  no contagiado   250301      Ucayali
#
# [120346 rows x 10 columns]

# %% [markdown]
# # HAY QUE HACER ESTO POR DEPARTAMENTO Y NIVEL DE PROBREZA EN EL COUNT IRIA LA VARIABLE SI LA PERSONA TIENE COVID

# %%
a2 = merge.groupby(["departamento","pobreza3"]).agg({'p4026':['count','median']})
a2
# Out:
#                            inghog2d                    gashog2d
#                                mean        median          mean        median
# pobreza3         nbi1
# no pobre         0     32760.041129  23489.980469  27007.277047  22380.583984
#                  1     19440.486354  16117.046875  18074.743293  15901.835938
# pobre extremo    0      9906.536155   8602.481445   7992.623172   7514.380859
#                  1     10618.739268   9501.479980   8556.479213   7883.616455
# pobre no extremo 0     15626.399573  11971.979492  13406.471448  12256.365234
#                  1     15045.327072  12720.994141  13271.803297  12754.585938

# %%
# Out:
# UsageError: Cell magic `%%shell` not found.
